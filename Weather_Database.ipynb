# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
from config import weather_api_key
import time
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 625

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e7be67db680e55c0875ab935aeb6f92

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        #convert rain and snow from mm to in
        try:
            city_rain = city_weather["rain"]["3h"] / 25.4
        except:
            city_rain = 0
        try:
            city_snow = city_weather["snow"]["3h"] / 25.4
        except:
            city_snow = 0
        
        
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,
                          "Rain inches (last 3 hrs)": city_rain,
                          "Snow inches (last 3 hrs)": city_snow})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | utrecht
# Processing Record 2 of Set 1 | neiafu
# Processing Record 3 of Set 1 | klaksvik
# Processing Record 4 of Set 1 | aklavik
# Processing Record 5 of Set 1 | quesnel
# Processing Record 6 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | bairiki
# Processing Record 10 of Set 1 | porto novo
# Processing Record 11 of Set 1 | santo anastacio
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | norman wells
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | kuytun
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | general pico
# Processing Record 20 of Set 1 | havelock
# Processing Record 21 of Set 1 | litovko
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | banda aceh
# Processing Record 24 of Set 1 | ryotsu
# Processing Record 25 of Set 1 | marsa matruh
# Processing Record 26 of Set 1 | katsuura
# Processing Record 27 of Set 1 | bafq
# Processing Record 28 of Set 1 | urengoy
# Processing Record 29 of Set 1 | codrington
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | kahului
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | plettenberg bay
# Processing Record 34 of Set 1 | saint-pierre
# Processing Record 35 of Set 1 | bambous virieux
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | skjervoy
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | birecik
# Processing Record 41 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | huarmey
# Processing Record 45 of Set 1 | hobyo
# Processing Record 46 of Set 1 | springbok
# Processing Record 47 of Set 1 | eldikan
# City not found. Skipping...
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | urumqi
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | arraial do cabo
# Processing Record 4 of Set 2 | naftah
# City not found. Skipping...
# Processing Record 5 of Set 2 | anadyr
# Processing Record 6 of Set 2 | puerto ayora
# Processing Record 7 of Set 2 | provideniya
# Processing Record 8 of Set 2 | cainta
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 11 of Set 2 | vao
# Processing Record 12 of Set 2 | torbay
# Processing Record 13 of Set 2 | san ramon de la nueva oran
# Processing Record 14 of Set 2 | oranjestad
# Processing Record 15 of Set 2 | hay river
# Processing Record 16 of Set 2 | meadow lake
# Processing Record 17 of Set 2 | guerrero negro
# Processing Record 18 of Set 2 | daru
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | upernavik
# Processing Record 22 of Set 2 | glendive
# Processing Record 23 of Set 2 | mount gambier
# Processing Record 24 of Set 2 | sola
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | ahuimanu
# Processing Record 27 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 2 | port hardy
# Processing Record 29 of Set 2 | kota belud
# Processing Record 30 of Set 2 | port lincoln
# Processing Record 31 of Set 2 | kodiak
# Processing Record 32 of Set 2 | miranorte
# City not found. Skipping...
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | sexsmith
# Processing Record 35 of Set 2 | goderich
# Processing Record 36 of Set 2 | fortuna
# Processing Record 37 of Set 2 | kutum
# Processing Record 38 of Set 2 | sterling
# Processing Record 39 of Set 2 | lapua
# Processing Record 40 of Set 2 | giyon
# Processing Record 41 of Set 2 | russell
# Processing Record 42 of Set 2 | mahajanga
# Processing Record 43 of Set 2 | la roche-sur-yon
# Processing Record 44 of Set 2 | dalhousie
# Processing Record 45 of Set 2 | yellowknife
# Processing Record 46 of Set 2 | moron
# Processing Record 47 of Set 2 | shizilu
# Processing Record 48 of Set 2 | lompoc
# Processing Record 49 of Set 2 | tecoanapa
# Processing Record 50 of Set 2 | namibe
# Processing Record 1 of Set 3 | seidu
# Processing Record 2 of Set 3 | pemangkat
# Processing Record 3 of Set 3 | coahuayana
# Processing Record 4 of Set 3 | peterhead
# Processing Record 5 of Set 3 | dalvik
# Processing Record 6 of Set 3 | hobart
# Processing Record 7 of Set 3 | cape town
# Processing Record 8 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 3 | qaanaaq
# Processing Record 10 of Set 3 | srednekolymsk
# Processing Record 11 of Set 3 | sheregesh
# Processing Record 12 of Set 3 | tuktoyaktuk
# Processing Record 13 of Set 3 | salinopolis
# Processing Record 14 of Set 3 | east london
# Processing Record 15 of Set 3 | vysokogornyy
# Processing Record 16 of Set 3 | kuching
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | mogzon
# Processing Record 19 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 3 | sibenik
# Processing Record 21 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 3 | vrangel
# Processing Record 23 of Set 3 | leningradskiy
# Processing Record 24 of Set 3 | redondela
# Processing Record 25 of Set 3 | erzin
# Processing Record 26 of Set 3 | cap malheureux
# Processing Record 27 of Set 3 | saint-philippe
# Processing Record 28 of Set 3 | lorengau
# Processing Record 29 of Set 3 | ponta do sol
# Processing Record 30 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 3 | harper
# Processing Record 32 of Set 3 | faanui
# Processing Record 33 of Set 3 | gimli
# Processing Record 34 of Set 3 | fort nelson
# Processing Record 35 of Set 3 | bethel
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | macas
# Processing Record 38 of Set 3 | esperance
# Processing Record 39 of Set 3 | los llanos de aridane
# Processing Record 40 of Set 3 | imbituba
# Processing Record 41 of Set 3 | ketchikan
# Processing Record 42 of Set 3 | san patricio
# Processing Record 43 of Set 3 | cherskiy
# Processing Record 44 of Set 3 | san cristobal
# Processing Record 45 of Set 3 | barrow
# Processing Record 46 of Set 3 | aykhal
# Processing Record 47 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 3 | maniitsoq
# Processing Record 49 of Set 3 | cangzhou
# Processing Record 50 of Set 3 | semnan
# Processing Record 1 of Set 4 | mecca
# Processing Record 2 of Set 4 | kavieng
# Processing Record 3 of Set 4 | bogande
# Processing Record 4 of Set 4 | san quintin
# Processing Record 5 of Set 4 | dali
# Processing Record 6 of Set 4 | mahebourg
# Processing Record 7 of Set 4 | kwinana
# Processing Record 8 of Set 4 | bangolo
# Processing Record 9 of Set 4 | nuuk
# Processing Record 10 of Set 4 | half moon bay
# Processing Record 11 of Set 4 | camacha
# Processing Record 12 of Set 4 | enshi
# Processing Record 13 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 4 | cidreira
# Processing Record 15 of Set 4 | riyadh
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | vanino
# Processing Record 18 of Set 4 | marathon
# Processing Record 19 of Set 4 | saskylakh
# Processing Record 20 of Set 4 | severo-kurilsk
# Processing Record 21 of Set 4 | dikson
# Processing Record 22 of Set 4 | kribi
# Processing Record 23 of Set 4 | dennery
# Processing Record 24 of Set 4 | atuona
# Processing Record 25 of Set 4 | saint george
# Processing Record 26 of Set 4 | makakilo city
# Processing Record 27 of Set 4 | nizhniy baskunchak
# Processing Record 28 of Set 4 | hamilton
# Processing Record 29 of Set 4 | deputatskiy
# Processing Record 30 of Set 4 | vuktyl
# Processing Record 31 of Set 4 | kittery
# Processing Record 32 of Set 4 | nikolskoye
# Processing Record 33 of Set 4 | pevek
# Processing Record 34 of Set 4 | sao filipe
# Processing Record 35 of Set 4 | nanortalik
# Processing Record 36 of Set 4 | hithadhoo
# Processing Record 37 of Set 4 | ryazhsk
# Processing Record 38 of Set 4 | bosaso
# Processing Record 39 of Set 4 | port-gentil
# Processing Record 40 of Set 4 | dulce nombre
# Processing Record 41 of Set 4 | pangnirtung
# Processing Record 42 of Set 4 | longyearbyen
# Processing Record 43 of Set 4 | vostok
# Processing Record 44 of Set 4 | qandala
# Processing Record 45 of Set 4 | carndonagh
# Processing Record 46 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 4 | bara
# Processing Record 48 of Set 4 | chernyshevskiy
# Processing Record 49 of Set 4 | taybad
# Processing Record 50 of Set 4 | urucui
# Processing Record 1 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 5 | kununurra
# Processing Record 3 of Set 5 | karratha
# Processing Record 4 of Set 5 | malmesbury
# Processing Record 5 of Set 5 | sunndalsora
# Processing Record 6 of Set 5 | kuremaa
# Processing Record 7 of Set 5 | bom jesus
# Processing Record 8 of Set 5 | natalinsk
# Processing Record 9 of Set 5 | pandan
# Processing Record 10 of Set 5 | guarapari
# Processing Record 11 of Set 5 | luanda
# Processing Record 12 of Set 5 | kindu
# Processing Record 13 of Set 5 | pringsewu
# Processing Record 14 of Set 5 | thompson
# Processing Record 15 of Set 5 | chulman
# Processing Record 16 of Set 5 | lumeje
# Processing Record 17 of Set 5 | port hedland
# Processing Record 18 of Set 5 | moose factory
# Processing Record 19 of Set 5 | doka
# Processing Record 20 of Set 5 | sitka
# Processing Record 21 of Set 5 | wahpeton
# Processing Record 22 of Set 5 | dingle
# Processing Record 23 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 5 | alice springs
# Processing Record 25 of Set 5 | komsomolskiy
# Processing Record 26 of Set 5 | gornopravdinsk
# Processing Record 27 of Set 5 | hasaki
# Processing Record 28 of Set 5 | geraldton
# Processing Record 29 of Set 5 | tsiroanomandidy
# Processing Record 30 of Set 5 | asau
# Processing Record 31 of Set 5 | naze
# Processing Record 32 of Set 5 | sindor
# Processing Record 33 of Set 5 | clyde river
# Processing Record 34 of Set 5 | tonantins
# Processing Record 35 of Set 5 | dhana
# Processing Record 36 of Set 5 | avera
# Processing Record 37 of Set 5 | iqaluit
# Processing Record 38 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 5 | quang ngai
# Processing Record 40 of Set 5 | abu dhabi
# Processing Record 41 of Set 5 | hambantota
# Processing Record 42 of Set 5 | apiai
# Processing Record 43 of Set 5 | korgen
# Processing Record 44 of Set 5 | cabedelo
# Processing Record 45 of Set 5 | cayenne
# Processing Record 46 of Set 5 | olonets
# Processing Record 47 of Set 5 | port keats
# Processing Record 48 of Set 5 | tura
# Processing Record 49 of Set 5 | beihai
# Processing Record 50 of Set 5 | colwyn bay
# Processing Record 1 of Set 6 | bengkulu
# Processing Record 2 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 3 of Set 6 | okhotsk
# Processing Record 4 of Set 6 | ostashkov
# Processing Record 5 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 6 | palmer
# Processing Record 7 of Set 6 | maragogi
# Processing Record 8 of Set 6 | andijon
# Processing Record 9 of Set 6 | takoradi
# Processing Record 10 of Set 6 | san luis
# Processing Record 11 of Set 6 | shirokiy
# Processing Record 12 of Set 6 | yuzhno-kurilsk
# Processing Record 13 of Set 6 | kaduqli
# Processing Record 14 of Set 6 | dubbo
# Processing Record 15 of Set 6 | carnarvon
# Processing Record 16 of Set 6 | goroka
# Processing Record 17 of Set 6 | pitimbu
# Processing Record 18 of Set 6 | baruun-urt
# Processing Record 19 of Set 6 | jiayuguan
# Processing Record 20 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 6 | svetlyy
# Processing Record 22 of Set 6 | honningsvag
# Processing Record 23 of Set 6 | roald
# Processing Record 24 of Set 6 | lagos
# Processing Record 25 of Set 6 | carutapera
# Processing Record 26 of Set 6 | narsaq
# Processing Record 27 of Set 6 | kongolo
# Processing Record 28 of Set 6 | vangaindrano
# Processing Record 29 of Set 6 | inhambane
# Processing Record 30 of Set 6 | lebu
# Processing Record 31 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 6 | garachine
# Processing Record 33 of Set 6 | mahanoro
# Processing Record 34 of Set 6 | casper
# Processing Record 35 of Set 6 | guaruja
# Processing Record 36 of Set 6 | vestmannaeyjar
# Processing Record 37 of Set 6 | christchurch
# Processing Record 38 of Set 6 | kaitangata
# Processing Record 39 of Set 6 | bogorodskoye
# Processing Record 40 of Set 6 | mokshan
# Processing Record 41 of Set 6 | rogun
# City not found. Skipping...
# Processing Record 42 of Set 6 | lucea
# Processing Record 43 of Set 6 | paso de los toros
# Processing Record 44 of Set 6 | tiksi
# Processing Record 45 of Set 6 | bubaque
# Processing Record 46 of Set 6 | jalu
# Processing Record 47 of Set 6 | notre-dame-du-lac
# Processing Record 48 of Set 6 | liverpool
# Processing Record 49 of Set 6 | mar del plata
# Processing Record 50 of Set 6 | kangaba
# Processing Record 1 of Set 7 | gat
# Processing Record 2 of Set 7 | avanigadda
# Processing Record 3 of Set 7 | kafue
# Processing Record 4 of Set 7 | seoul
# Processing Record 5 of Set 7 | iwaki
# Processing Record 6 of Set 7 | faya
# Processing Record 7 of Set 7 | oistins
# Processing Record 8 of Set 7 | saint-augustin
# Processing Record 9 of Set 7 | ferme-neuve
# Processing Record 10 of Set 7 | alekseyevka
# Processing Record 11 of Set 7 | sabang
# Processing Record 12 of Set 7 | monrovia
# Processing Record 13 of Set 7 | kavaratti
# Processing Record 14 of Set 7 | laguna
# Processing Record 15 of Set 7 | quatre cocos
# Processing Record 16 of Set 7 | torbat-e jam
# Processing Record 17 of Set 7 | noumea
# Processing Record 18 of Set 7 | camana
# Processing Record 19 of Set 7 | gobabis
# Processing Record 20 of Set 7 | tuy hoa
# Processing Record 21 of Set 7 | den helder
# Processing Record 22 of Set 7 | cruzilia
# Processing Record 23 of Set 7 | crotone
# Processing Record 24 of Set 7 | assiniboia
# Processing Record 25 of Set 7 | key west
# Processing Record 26 of Set 7 | yulara
# Processing Record 27 of Set 7 | sisimiut
# Processing Record 28 of Set 7 | solothurn
# Processing Record 29 of Set 7 | redding
# Processing Record 30 of Set 7 | hami
# Processing Record 31 of Set 7 | aitape
# Processing Record 32 of Set 7 | ugra
# Processing Record 33 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 7 | atar
# Processing Record 35 of Set 7 | warrington
# Processing Record 36 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 7 | marang
# Processing Record 38 of Set 7 | saldanha
# Processing Record 39 of Set 7 | pisco
# Processing Record 40 of Set 7 | thai nguyen
# Processing Record 41 of Set 7 | chauk
# Processing Record 42 of Set 7 | luderitz
# Processing Record 43 of Set 7 | usinsk
# Processing Record 44 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 7 | retiro
# Processing Record 46 of Set 7 | pangai
# Processing Record 47 of Set 7 | rassvet
# Processing Record 48 of Set 7 | santa cruz
# Processing Record 49 of Set 7 | muravlenko
# Processing Record 50 of Set 7 | labuhan
# Processing Record 1 of Set 8 | yekepa
# Processing Record 2 of Set 8 | khandagayty
# Processing Record 3 of Set 8 | ulyanovo
# City not found. Skipping...
# Processing Record 4 of Set 8 | kisesa
# Processing Record 5 of Set 8 | mopipi
# Processing Record 6 of Set 8 | poum
# Processing Record 7 of Set 8 | kyzyl-suu
# Processing Record 8 of Set 8 | kenitra
# Processing Record 9 of Set 8 | smolenka
# Processing Record 10 of Set 8 | calabozo
# Processing Record 11 of Set 8 | touros
# Processing Record 12 of Set 8 | khandyga
# Processing Record 13 of Set 8 | bowen
# Processing Record 14 of Set 8 | mahaicony
# City not found. Skipping...
# Processing Record 15 of Set 8 | springdale
# Processing Record 16 of Set 8 | iracoubo
# Processing Record 17 of Set 8 | puerto varas
# Processing Record 18 of Set 8 | manggar
# Processing Record 19 of Set 8 | fairbanks
# Processing Record 20 of Set 8 | neryungri
# Processing Record 21 of Set 8 | calvia
# Processing Record 22 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 8 | tasiilaq
# Processing Record 24 of Set 8 | thinadhoo
# Processing Record 25 of Set 8 | nanpiao
# Processing Record 26 of Set 8 | gamba
# Processing Record 27 of Set 8 | goma
# Processing Record 28 of Set 8 | shingu
# Processing Record 29 of Set 8 | sao lourenco do sul
# Processing Record 30 of Set 8 | ostrovnoy
# Processing Record 31 of Set 8 | nantucket
# Processing Record 32 of Set 8 | artyom
# Processing Record 33 of Set 8 | dalen
# Processing Record 34 of Set 8 | port macquarie
# Processing Record 35 of Set 8 | wanning
# Processing Record 36 of Set 8 | te anau
# Processing Record 37 of Set 8 | beloha
# Processing Record 38 of Set 8 | acapulco
# Processing Record 39 of Set 8 | varzea da palma
# Processing Record 40 of Set 8 | colesberg
# Processing Record 41 of Set 8 | pauini
# Processing Record 42 of Set 8 | waingapu
# Processing Record 43 of Set 8 | sakakah
# Processing Record 44 of Set 8 | yar-sale
# Processing Record 45 of Set 8 | yumen
# Processing Record 46 of Set 8 | eureka
# Processing Record 47 of Set 8 | umred
# Processing Record 48 of Set 8 | ashland
# Processing Record 49 of Set 8 | sinnamary
# Processing Record 50 of Set 8 | phalodi
# Processing Record 1 of Set 9 | kitgum
# Processing Record 2 of Set 9 | kotido
# Processing Record 3 of Set 9 | tautira
# Processing Record 4 of Set 9 | riohacha
# Processing Record 5 of Set 9 | yerbogachen
# Processing Record 6 of Set 9 | mao
# Processing Record 7 of Set 9 | flinders
# Processing Record 8 of Set 9 | grand gaube
# Processing Record 9 of Set 9 | shenkursk
# Processing Record 10 of Set 9 | berekua
# Processing Record 11 of Set 9 | paramonga
# Processing Record 12 of Set 9 | dargaville
# Processing Record 13 of Set 9 | haapiti
# Processing Record 14 of Set 9 | caldwell
# Processing Record 15 of Set 9 | dogondoutchi
# Processing Record 16 of Set 9 | arlit
# Processing Record 17 of Set 9 | whitehorse
# Processing Record 18 of Set 9 | shimoda
# Processing Record 19 of Set 9 | athabasca
# Processing Record 20 of Set 9 | margate
# Processing Record 21 of Set 9 | denpasar
# Processing Record 22 of Set 9 | santa cruz del sur
# Processing Record 23 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 9 | constitucion
# Processing Record 25 of Set 9 | verkhnevilyuysk
# Processing Record 26 of Set 9 | himora
# City not found. Skipping...
# Processing Record 27 of Set 9 | honiara
# Processing Record 28 of Set 9 | sistranda
# Processing Record 29 of Set 9 | nouadhibou
# Processing Record 30 of Set 9 | north bend
# Processing Record 31 of Set 9 | bambanglipuro
# Processing Record 32 of Set 9 | dong hoi
# Processing Record 33 of Set 9 | san policarpo
# Processing Record 34 of Set 9 | olafsvik
# Processing Record 35 of Set 9 | prince george
# Processing Record 36 of Set 9 | vila franca do campo
# Processing Record 37 of Set 9 | korla
# Processing Record 38 of Set 9 | benjamin constant
# Processing Record 39 of Set 9 | santiago de cao
# Processing Record 40 of Set 9 | inirida
# Processing Record 41 of Set 9 | westport
# Processing Record 42 of Set 9 | nagato
# Processing Record 43 of Set 9 | taitung
# Processing Record 44 of Set 9 | guatire
# Processing Record 45 of Set 9 | zhigansk
# Processing Record 46 of Set 9 | painesville
# Processing Record 47 of Set 9 | basco
# Processing Record 48 of Set 9 | mayo
# Processing Record 49 of Set 9 | eresos
# Processing Record 50 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 1 of Set 10 | dubrovnik
# Processing Record 2 of Set 10 | octeville
# Processing Record 3 of Set 10 | krasnyy yar
# Processing Record 4 of Set 10 | chufarovo
# Processing Record 5 of Set 10 | galeana
# Processing Record 6 of Set 10 | lamu
# Processing Record 7 of Set 10 | havre-saint-pierre
# Processing Record 8 of Set 10 | pagman
# City not found. Skipping...
# Processing Record 9 of Set 10 | kemijarvi
# City not found. Skipping...
# Processing Record 10 of Set 10 | mae sai
# Processing Record 11 of Set 10 | yarada
# Processing Record 12 of Set 10 | otane
# Processing Record 13 of Set 10 | coihaique
# Processing Record 14 of Set 10 | soure
# Processing Record 15 of Set 10 | quzhou
# Processing Record 16 of Set 10 | souillac
# Processing Record 17 of Set 10 | along
# Processing Record 18 of Set 10 | romanovo
# Processing Record 19 of Set 10 | baherden
# Processing Record 20 of Set 10 | laja
# Processing Record 21 of Set 10 | challans
# Processing Record 22 of Set 10 | mehamn
# Processing Record 23 of Set 10 | harqalah
# Processing Record 24 of Set 10 | plouzane
# Processing Record 25 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 10 | olden
# Processing Record 27 of Set 10 | chama
# Processing Record 28 of Set 10 | dunedin
# Processing Record 29 of Set 10 | vanavara
# Processing Record 30 of Set 10 | lazaro cardenas
# Processing Record 31 of Set 10 | omboue
# Processing Record 32 of Set 10 | de-kastri
# Processing Record 33 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 10 | merauke
# Processing Record 35 of Set 10 | acarau
# Processing Record 36 of Set 10 | coquimbo
# Processing Record 37 of Set 10 | hofn
# Processing Record 38 of Set 10 | narrabri
# Processing Record 39 of Set 10 | puerto madryn
# Processing Record 40 of Set 10 | hazorasp
# Processing Record 41 of Set 10 | pochutla
# Processing Record 42 of Set 10 | gerash
# Processing Record 43 of Set 10 | manyana
# Processing Record 44 of Set 10 | kijang
# Processing Record 45 of Set 10 | kadnikov
# Processing Record 46 of Set 10 | kloulklubed
# Processing Record 47 of Set 10 | mercedes
# Processing Record 48 of Set 10 | ankang
# Processing Record 49 of Set 10 | longhua
# Processing Record 50 of Set 10 | san jose
# Processing Record 1 of Set 11 | dongli
# Processing Record 2 of Set 11 | caldas novas
# Processing Record 3 of Set 11 | calama
# Processing Record 4 of Set 11 | beberibe
# Processing Record 5 of Set 11 | alofi
# Processing Record 6 of Set 11 | mora
# Processing Record 7 of Set 11 | varkaus
# Processing Record 8 of Set 11 | raga
# Processing Record 9 of Set 11 | kathmandu
# Processing Record 10 of Set 11 | aguimes
# Processing Record 11 of Set 11 | nemuro
# Processing Record 12 of Set 11 | scarborough
# Processing Record 13 of Set 11 | joensuu
# Processing Record 14 of Set 11 | senador jose porfirio
# Processing Record 15 of Set 11 | kaeo
# Processing Record 16 of Set 11 | saint-remi
# Processing Record 17 of Set 11 | candawaga
# City not found. Skipping...
# Processing Record 18 of Set 11 | bilibino
# Processing Record 19 of Set 11 | seymchan
# Processing Record 20 of Set 11 | buala
# Processing Record 21 of Set 11 | natal
# Processing Record 22 of Set 11 | lida
# Processing Record 23 of Set 11 | prigen
# Processing Record 24 of Set 11 | altamira
# Processing Record 25 of Set 11 | salalah
# Processing Record 26 of Set 11 | tiarei
# Processing Record 27 of Set 11 | panaba
# Processing Record 28 of Set 11 | zunyi
# Processing Record 29 of Set 11 | glamoc
# Processing Record 30 of Set 11 | la rioja
# Processing Record 31 of Set 11 | metro
# Processing Record 32 of Set 11 | cabo san lucas
# Processing Record 33 of Set 11 | birnin kebbi
# Processing Record 34 of Set 11 | talnakh
# Processing Record 35 of Set 11 | babushkin
# Processing Record 36 of Set 11 | la ronge
# Processing Record 37 of Set 11 | aguilas
# Processing Record 38 of Set 11 | nizhnevartovsk
# Processing Record 39 of Set 11 | san carlos de bariloche
# Processing Record 40 of Set 11 | imperia
# Processing Record 41 of Set 11 | marsabit
# Processing Record 42 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 43 of Set 11 | rorvik
# Processing Record 44 of Set 11 | villa bruzual
# Processing Record 45 of Set 11 | sassandra
# Processing Record 46 of Set 11 | nikolayevsk-na-amure
# Processing Record 47 of Set 11 | amloh
# Processing Record 48 of Set 11 | ipaussu
# Processing Record 49 of Set 11 | solnechnyy
# Processing Record 50 of Set 11 | beira
# Processing Record 1 of Set 12 | fraserburgh
# Processing Record 2 of Set 12 | lithgow
# Processing Record 3 of Set 12 | mount isa
# Processing Record 4 of Set 12 | airai
# Processing Record 5 of Set 12 | mbanza-ngungu
# Processing Record 6 of Set 12 | gondanglegi
# Processing Record 7 of Set 12 | agadez
# Processing Record 8 of Set 12 | safaqis
# City not found. Skipping...
# Processing Record 9 of Set 12 | angoche
# Processing Record 10 of Set 12 | colac
# Processing Record 11 of Set 12 | svetlaya
# Processing Record 12 of Set 12 | chuy
# Processing Record 13 of Set 12 | panzhihua
# Processing Record 14 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 15 of Set 12 | barcelona
# Processing Record 16 of Set 12 | gazanjyk
# Processing Record 17 of Set 12 | iringa
# Processing Record 18 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 19 of Set 12 | alegrete
# Processing Record 20 of Set 12 | sierra vista
# Processing Record 21 of Set 12 | khomeynishahr
# City not found. Skipping...
# Processing Record 22 of Set 12 | vardo
# Processing Record 23 of Set 12 | namatanai
# Processing Record 24 of Set 12 | akyab
# Processing Record 25 of Set 12 | makhinjauri
# Processing Record 26 of Set 12 | san juan
# Processing Record 27 of Set 12 | alice town
# Processing Record 28 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 29 of Set 12 | taloqan
# Processing Record 30 of Set 12 | nosy varika
# Processing Record 31 of Set 12 | egvekinot
# Processing Record 32 of Set 12 | male
# Processing Record 33 of Set 12 | ponta delgada
# Processing Record 34 of Set 12 | caravelas
# Processing Record 35 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 12 | hefei
# Processing Record 37 of Set 12 | road town
# Processing Record 38 of Set 12 | kailua
# Processing Record 39 of Set 12 | santa rosalia
# Processing Record 40 of Set 12 | aban
# Processing Record 41 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 12 | byron bay
# Processing Record 43 of Set 12 | xuddur
# Processing Record 44 of Set 12 | kiruna
# Processing Record 45 of Set 12 | assela
# City not found. Skipping...
# Processing Record 46 of Set 12 | pacific grove
# Processing Record 47 of Set 12 | erenhot
# Processing Record 48 of Set 12 | tuatapere
# Processing Record 49 of Set 12 | patacamaya
# Processing Record 50 of Set 12 | portel
# Processing Record 1 of Set 13 | chengde
# Processing Record 2 of Set 13 | paka
# Processing Record 3 of Set 13 | dubki
# Processing Record 4 of Set 13 | ugoofaaru
# Processing Record 5 of Set 13 | saint-georges
# Processing Record 6 of Set 13 | dedza
# Processing Record 7 of Set 13 | kidal
# Processing Record 8 of Set 13 | bayan
# Processing Record 9 of Set 13 | lagoa
# Processing Record 10 of Set 13 | nhulunbuy
# Processing Record 11 of Set 13 | sobolevo
# Processing Record 12 of Set 13 | pampa
# Processing Record 13 of Set 13 | apam
# Processing Record 14 of Set 13 | finschhafen
# Processing Record 15 of Set 13 | mogocha
# Processing Record 16 of Set 13 | dalbandin
# Processing Record 17 of Set 13 | bilma
# Processing Record 18 of Set 13 | porbandar
# Processing Record 19 of Set 13 | udachnyy
# Processing Record 20 of Set 13 | portobelo
# Processing Record 21 of Set 13 | waipawa
# Processing Record 22 of Set 13 | say
# Processing Record 23 of Set 13 | danielskuil
# Processing Record 24 of Set 13 | whitianga
# Processing Record 25 of Set 13 | waspan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country                 Date    Lat     Lng  Max Temp  \
# 0          Utrecht      NL  2020-02-24 05:52:38  52.00    5.25      43.0
# 1           Neiafu      TO  2020-02-24 05:55:24 -18.65 -173.98      84.2
# 2         Klaksvik      FO  2020-02-24 05:55:25  62.23   -6.59      39.2
# 3          Aklavik      CA  2020-02-24 05:55:25  68.22 -135.01      -4.0
# 4          Quesnel      CA  2020-02-24 05:55:25  53.00 -122.50      28.4
# 5       Georgetown      MY  2020-02-24 05:55:12   5.41  100.34      89.6
# 6        Busselton      AU  2020-02-24 05:55:25 -33.65  115.33      77.0
# 7          Bairiki      KI  2020-02-24 05:55:26   1.33  172.98      87.8
# 8       Porto Novo      BJ  2020-02-24 05:55:26   6.50    2.60      84.2
# 9  Santo Anastacio      BR  2020-02-24 05:52:09 -21.84  -51.61      73.4
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        86          90        6.93     overcast clouds
# 1        79          20        9.17          few clouds
# 2        69          80       17.22          light snow
# 3        76          90        2.24          light snow
# 4       100          90        3.36                mist
# 5        55          20       10.29          few clouds
# 6        36          99       13.78     overcast clouds
# 7        74          20        6.93          few clouds
# 8        89          40        6.93    scattered clouds
# 9        69          75       10.29       broken clouds
#
#    Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                       0.0                  0.000000
# 1                       0.0                  0.000000
# 2                       0.0                  0.014961
# 3                       0.0                  0.000000
# 4                       0.0                  0.000000
# 5                       0.0                  0.000000
# 6                       0.0                  0.000000
# 7                       0.0                  0.000000
# 8                       0.0                  0.000000
# 9                       0.0                  0.000000

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_challenge.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df["Rain inches (last 3 hrs)"].gt(0).sum()
# Out:
# 53

# %%
city_data_df["Snow inches (last 3 hrs)"].gt(0).sum()
# Out:
# 28
